# %%
import pyodbc

# %%
import pandas as pd

# %%
# Define connection parameters
server = '' # e.g., 'localhost\\SQLEXPRESS' or '192.168.1.100'
database = 'Testing'
driver = 'ODBC Driver 17 for SQL Server'

# Create connection string using Windows Authentication
conn_str = f'DRIVER={{{driver}}};SERVER={server};DATABASE={database};Trusted_Connection=yes;'

# Connect to the database
try:
    conn = pyodbc.connect(conn_str)
    print("Connection successful!")

    # Example query
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM Subjects")
    for row in cursor.fetchall():
        print(row)

    conn.close()

except Exception as e:
    print("Connection failed:", e)
# Out:
# Connection failed: ('HYT00', '[HYT00] [Microsoft][ODBC Driver 17 for SQL Server]Login timeout expired (0) (SQLDriverConnect)')

# %%
print(pyodbc.drivers())
# Out:
# ['ODBC Driver 17 for SQL Server']
